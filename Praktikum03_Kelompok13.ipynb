# %% [markdown]
# <a href="https://colab.research.google.com/github/pramrahmansah/visualisasidata/blob/main/Praktikum03_Kelompok13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Data sample
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
product_A_sales = [10, 20, 15, 25, 30, 45, 40, 50, 60, 55, 65, 70]
product_B_sales = [5, 10, 8, 15, 18, 20, 22, 30, 25, 35, 40, 45]

# Line Plot
plt.plot(months, product_A_sales)
plt.title('Penjualan Produk A Per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Penjualan')
plt.show()

# %% [markdown]
# Multiple Line Plot & Customizations

# %%
from matplotlib.lines import lineStyles
import matplotlib.pyplot as plt

# Data sample
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
product_A_sales = [10, 20, 15, 25, 30, 45, 40, 50, 60, 55, 65, 70]
product_B_sales = [5, 10, 8, 15, 18, 20, 22, 30, 25, 35, 40, 45]

# Line Plot
plt.plot(months, product_A_sales, label='Product A', linestyle="--", marker='o')
plt.plot(months, product_B_sales, label='Product B', linestyle="-", marker='x')
plt.title('Penjualan Produk Per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Penjualan')
plt.legend()
plt.show()

# %% [markdown]
# Jenis Garis untuk Menunjukan Tren

# %%
#Data Sample Tambahan
product_C_sales= [18,22,25,28,32,42,45,48,52,56,60,62]
product_D_sales= [7,9,11,13,16,18,20,23,28,25,27,16]
# Line Plot
plt.plot(months, product_A_sales, label='Product A', linestyle="--", color='purple')
plt.plot(months, product_B_sales, label='Product B', linestyle="-", color='red')
plt.plot(months, product_C_sales, label='Product C', linestyle=":", color="blue") # Corrected linestyle to ':'
plt.plot(months, product_D_sales, label='Product D', linestyle=":", color="green")
plt.title('Penjualan Produk Per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Penjualan')
plt.legend()
plt.show()

# %% [markdown]
# Subplot Pada LineChart

# %%
import matplotlib.pyplot as plt

# Data sample
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
product_C_sales= [18,22,25,28,32,42,45,48,52,56,60,62]
product_D_sales= [7,9,11,13,16,18,20,23,28,25,27,16]

# Line Plot
fig, axs = plt.subplots(2, 1, figsize=(10, 8))

# Plot for Product C
axs[0].plot(months, product_C_sales, label='Product C', color='green', marker='d')
axs[0].set_title('Penjualan Produk Per Bulan')
axs[0].set_xlabel('Bulan')
axs[0].set_ylabel('Jumlah Penjualan')
axs[0].legend()
axs[0].grid(True)

# Plot for Product D
axs[1].plot(months, product_D_sales, label='Product D', color='purple', marker='s')
axs[1].set_title('Penjualan Produk Per Bulan')
axs[1].set_xlabel('Bulan')
axs[1].set_ylabel('Jumlah Penjualan')
axs[1].legend()
axs[1].grid(True)

plt.tight_layout()
plt.show()
